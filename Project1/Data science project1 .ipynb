# %% [markdown]
# Esta primeira célula vai armazenar os dados do meu arquivo .csv e destacar só os dados importantes para a pesquisa

# %%
import pandas as pd

dados_btc = pd.read_csv(
                    "btc.csv",
                    sep=',',
                    index_col='Date',
                    usecols=['Date','Name','High','Low','Close'])
    
print(dados_btc)
# Out:
#                         Name          High           Low         Close
# Date
# 2013-04-29 23:59:59  Bitcoin    147.488007    134.000000    144.539993
# 2013-04-30 23:59:59  Bitcoin    146.929993    134.050003    139.000000
# 2013-05-01 23:59:59  Bitcoin    139.889999    107.720001    116.989998
# 2013-05-02 23:59:59  Bitcoin    125.599998     92.281898    105.209999
# 2013-05-03 23:59:59  Bitcoin    108.127998     79.099998     97.750000
# ...                      ...           ...           ...           ...
# 2021-07-02 23:59:59  Bitcoin  33939.588699  32770.680780  33897.048590
# 2021-07-03 23:59:59  Bitcoin  34909.259899  33402.696536  34668.548402
# 2021-07-04 23:59:59  Bitcoin  35937.567147  34396.477458  35287.779766
# 2021-07-05 23:59:59  Bitcoin  35284.344430  33213.661034  33746.002456
# 2021-07-06 23:59:59  Bitcoin  35038.536363  33599.916169  34235.193451
#
# [2991 rows x 4 columns]

# %% [markdown]
# Na imagem abaixo é possível ver a curva no gráfico de histórico de preços do bitcoin, em destaque o período em que essa pesquisa está analisando: no ano de 2020 o preço da moeda aumentou drásticamente.

# %% [markdown]
# ![dados1.png](attachment:dados1.png)

# %% [markdown]
# Agora no segundo código é indicado os dados de variações do preço do Dólar em Reais(USD/BRL):

# %%
dados_USD = pd.read_csv(
                        "USD.csv",
                        sep=',',
                        index_col='Data',
                        usecols=['Data', 'Máxima','Mínima','Var%'])
print(dados_USD)
# Out:
#             Máxima  Mínima    Var%
# Data
# 28.12.2020  5,3127  5,1642   0,58%
# 25.12.2020  5,2167  5,2167   0,00%
# 24.12.2020  5,2167  5,2167  -0,00%
# 23.12.2020  5,2211  5,1282   1,10%
# 22.12.2020  5,1724  5,1089   0,73%
# ...            ...     ...     ...
# 03.04.2020  5,3534  5,2556   1,85%
# 02.04.2020  5,2843  5,2218   0,08%
# 01.04.2020  5,2740  5,2203   0,85%
# 31.03.2020  5,2150  5,1677   0,21%
# 30.03.2020  5,1957  5,1126   1,84%
#
# [196 rows x 3 columns]

# %%
Na próxima imagem exibe a variação do Dólar e sua queda no ano de eleições em 2020:

# %% [markdown]
# ![dados22.png](attachment:dados22.png)
